# %% [markdown]
# <a href="https://colab.research.google.com/github/ritigupta07/Image-translation-Deep-Learning/blob/master/create_csv_file_with_headers_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#The .csv file is created in the drive. The dataset stored in drive is
#read and file names are inserted in the .csv file. This csv file will 
#be used in Deep learning model.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
directory ='/content/drive/My Drive/dataset_298/english'

for filename in os.listdir(directory):
  print(filename)

# %%
datasetcsv ='/content/drive/My Drive/dataSet.csv'
import csv
directory ='/content/drive/My Drive/dataset_298/english'
with open('/content/drive/My Drive/dataSet.csv', mode='w') as dataset_file:
    dataset_writer = csv.writer(dataset_file, delimiter=',')
    dataset_writer.writerow(['image','english','machine_translation','context','hindi'])
    for filename in os.listdir(directory):
      if(filename != ".DS_Store"):
        print(filename)
        dataset_writer.writerow([filename, 'boy', 'ladka','gun','ladka'])
# Out:
# 117.png
# 8.png
# 9.png
# 14.png
# 15.png
# 17.png
# 16.png
# 12.png
# 13.png
# 11.png
# 10.png
# 21.png
# 20.png
# 22.png
# 23.png
# 18.png
# 24.png
# 25.png
# 19.png
# 4.png
# 5.png
# 7.png
# 6.png
# 2.png
# 3.png
# 1.png
# 176.png
# 77.png
# 162.png
# 88.png
# 189.png
# 228.png
# 200.png
# 215.png
# 229.png
# 201.png
# 188.png
# 62.png
# 63.png
# 76.png
# 214.png
# 163.png
# 149.png
# 74.png
# 48.png
# 217.png
# 89.png
# 161.png
# 60.png
# 175.png
# 177.png
# 216.png
# 49.png
# 75.png
# 61.png
# 148.png
# 174.png
# 160.png
# 164.png
# 202.png
# 203.png
# 65.png
# 71.png
# 212.png
# 206.png
# 70.png
# 207.png
# 59.png
# 213.png
# 158.png
# 170.png
# 64.png
# 159.png
# 99.png
# 198.png
# 58.png
# 171.png
# 72.png
# 167.png
# 173.png
# 165.png
# 66.png
# 205.png
# 211.png
# 204.png
# 73.png
# 67.png
# 210.png
# 238.png
# 199.png
# 239.png
# 172.png
# 129.png
# 101.png
# 115.png
# 100.png
# 28.png
# 29.png
# 98.png
# 166.png
# 114.png
# 102.png
# 116.png
# 248.png
# 249.png
# 103.png
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/dataSet.csv')
df.set_index('image', inplace=True)
df.loc['21.png','english'] = 'girl'
df.to_csv('/content/drive/My Drive/dataSet4.csv')
